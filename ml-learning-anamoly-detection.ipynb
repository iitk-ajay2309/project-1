# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# exampele:
# Fraud detection
# Manufacturing
# Monitering process anamolies
#
# Idea:
#
# if P(x) < e (probability of event is less than some value, it is anamoly)
#
# More like an unsupervised learning, where outliers are the anamolies
#
# Gaussian Distribution: normal distribution
#
# x~ N($\mu, \sigma^2$)

# %% [markdown]
# $\mu $ = mean of parameter values
# $\sigma^2$ = variance = mean of sq of diff of vlaues from mean

# %% [markdown]
# ## modelling gaussing distribution
#
# training set: {x(i),...}
#
# compute p(x) = $p(x_1, \mu_1, \sigma_1^2)p(x_2, \mu_2, \sigma_2^2)..p(x_n).$
# multiplication of probabilities for different input features
#
# if p(x) < e, its an anamoly

# %% [markdown]
# How to apply for fraud detection?
#
# We have labelled data: y = 0 normal and y = 1 anamolous
#
# Training: we can use normal examples, or only minimum anamoulurs
#
# eg 10000 normal, 20 frauds
#
# we can break down as 6000 normal for training,
# 2000 normal + 10 anomalous for CV
# and 2000 normal + 10 anomalous for test
#
# with training set we can know the minimum normal probable example that can be used to compute e value
#
#
# Evaluation metrics:
# - True positives, false positives, false negative,True negatives etc
#
# - Compute precison/ recall
#
# - compute F1 score
#
# Can use CV set to choose e value as well

# %% [markdown]
# Use anamoly detection when there are large number of negative examples, while use Supervised learning models if positves ~ negative exaples.
#
# Also we can use anamoly detection if future anamolies looks nothing like examples we have seen so far.

# %% [markdown]
# What featurees to use when doing anamoly detection
#
#
#
# Try to see what featueres have gaussian features first
# Non-gaussian featuere: Try to transform the data to gauusian for skewed (try log(x + c), or x^ 1/k etc), or non gaussians;

# %% [markdown]
# Error analysis for anamoly detection:
#
# we want P(x) high for normal exaple and p(x) less for anomalous examples, that means feature transformation
#
# some times we can create new features using
# xnew  = xn / xm or some other mathematical operation
#
#
# Multivariate Gaussian distribtion problem:
#
# ![![image.png](attachment:add047a3-c889-4b6d-83c8-a4b5df6023cf.png)](http://)
#
# what if x1 and x2 make such a combination that the collective probability comes all correct for an anamolous case. This is one con with multivariate
#
# In that case we use Multivariate Gaussian Distribution that does not use multiplication of individual probabilities:
# p(x) = $\pi p(xi) $
#
# so $\mu ~ R^n , \SIGMA ~ R^(n*n)$ (coveraince matrix) or the determinant of the matrix
